# %% [markdown]
# # Datathink 2023
# Roma 2023. Biblioteca Hertziana + DSV@UZH + Max Planck Society
# # Sensing data fusion
# Javier Argota Sánchez-Vaquerizo
#
# *Computational Social Science* | **ETHZ Zürich**
# javier.argota@gess.ethz.ch
#
#
# This notebook illustrates how to combine and aggregates different types of data collected from different sensors:
# - GPS tracks from location devices (i.e. smartphones, smartwatches, activity trackers, etc.)
# - Gas / air quality data from the CoCi's CoSense unit by COSS@ETHZ
# - GQ multimeter for electric+electromagnetic+radiofrequency

# %%
# We first mount your Google Drive folder in that notebook so that we can download and upload files.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Reivajar/datathink_2023.git
# Out:
# fatal: destination path 'datathink_2023' already exists and is not an empty directory.

# %%
# install libraries
# !pip install gpxo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gpxo in /usr/local/lib/python3.8/dist-packages (0.1.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from gpxo) (1.3.5)
# Requirement already satisfied: mplleaflet in /usr/local/lib/python3.8/dist-packages (from gpxo) (0.0.5)
# Requirement already satisfied: vincenty in /usr/local/lib/python3.8/dist-packages (from gpxo) (0.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from gpxo) (1.22.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from gpxo) (6.0.0)
# Requirement already satisfied: gpxpy in /usr/local/lib/python3.8/dist-packages (from gpxo) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from gpxo) (3.5.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->gpxo) (3.14.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (4.38.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from mplleaflet->gpxo) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from mplleaflet->gpxo) (2.11.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->gpxo) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->mplleaflet->gpxo) (2.0.1)

# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Defining wd

# %%
folder = "/content/datathink_2023/test_roma_20230228/sensor_GQ" #os.getcwd()

# %% [markdown]
# # Importing GPS tracks

# %% [markdown]
# ## method 2 with gpxo

# %%
import gpxo
paths = []
for file in sorted(os.listdir(folder)):
    if file.endswith(".gpx"):
        paths.append(os.path.join(folder, file))
print(sorted(paths))

df_gps = pd.DataFrame()
for gps_tracks in paths:
    gps_data = gpxo.Track(gps_tracks)
    df_gps_temp = gps_data.data
    df_gps = pd.concat([df_gps, df_gps_temp])
df_gps
# Out:
# ['/content/datathink_2023/test_roma_20230228/sensor_GQ/2023-02-28_28_févr._2023_10_h_33_min_14_s.gpx']
#                          latitude (°)  longitude (°)  distance (km)  \
# time
# 2023-02-28 09:33:17.136     41.910707      12.476449       0.000000
# 2023-02-28 09:35:18.000     41.910713      12.476418       0.002665
# 2023-02-28 09:37:19.000     41.910680      12.476336       0.010384
# 2023-02-28 09:39:06.000     41.910732      12.476434       0.020392
# 2023-02-28 09:41:07.000     41.910676      12.476492       0.028195
# ...                               ...            ...            ...
# 2023-02-28 11:52:01.000     41.905513      12.483953       6.309155
# 2023-02-28 11:52:13.000     41.905501      12.484088       6.320444
# 2023-02-28 11:52:19.000     41.905461      12.484198       6.330619
# 2023-02-28 11:52:24.000     41.905422      12.484338       6.343016
# 2023-02-28 11:55:52.000     41.906158      12.484462       6.425386
#
#                          compass (°)  duration (s)  velocity (km/h)  \
# time
# 2023-02-28 09:33:17.136   282.658637         0.000         0.079378
# 2023-02-28 09:35:18.000   262.385479       120.864         0.154475
# 2023-02-28 09:37:19.000   328.645575       241.864         0.286474
# 2023-02-28 09:39:06.000    98.552810       348.864         0.287647
# 2023-02-28 09:41:07.000    88.420928       469.864         0.156243
# ...                              ...           ...              ...
# 2023-02-28 11:52:01.000   106.211092      8323.864         5.254500
# 2023-02-28 11:52:13.000   106.483369      8335.864         5.198900
# 2023-02-28 11:52:19.000   113.265065      8341.864         7.643640
# 2023-02-28 11:52:24.000    58.777930      8346.864         8.749779
# 2023-02-28 11:55:52.000     7.161679      8554.864         1.425635
#
#                          elevation (m)
# time
# 2023-02-28 09:33:17.136           53.0
# 2023-02-28 09:35:18.000           59.0
# 2023-02-28 09:37:19.000           54.0
# 2023-02-28 09:39:06.000           60.0
# 2023-02-28 09:41:07.000           64.0
# ...                                ...
# 2023-02-28 11:52:01.000           76.0
# 2023-02-28 11:52:13.000           76.0
# 2023-02-28 11:52:19.000           76.0
# 2023-02-28 11:52:24.000           77.0
# 2023-02-28 11:55:52.000           42.0
#
# [517 rows x 7 columns]

# %%
df_gps.index
# Out:
# DatetimeIndex(['2023-02-28 09:33:17.136000',        '2023-02-28 09:35:18',
#                       '2023-02-28 09:37:19',        '2023-02-28 09:39:06',
#                       '2023-02-28 09:41:07',        '2023-02-28 09:43:08',
#                       '2023-02-28 09:44:13',        '2023-02-28 09:44:22',
#                       '2023-02-28 09:44:30',        '2023-02-28 09:44:39',
#                ...
#                       '2023-02-28 11:51:12',        '2023-02-28 11:51:25',
#                       '2023-02-28 11:51:35',        '2023-02-28 11:51:45',
#                       '2023-02-28 11:51:55',        '2023-02-28 11:52:01',
#                       '2023-02-28 11:52:13',        '2023-02-28 11:52:19',
#                       '2023-02-28 11:52:24',        '2023-02-28 11:55:52'],
#               dtype='datetime64[ns]', name='time', length=517, freq=None)

# %%
# read Datetime Index in GMT, convert to CET and remove timezone while preserving local time
df_gps["time_CET"] = df_gps.index.tz_localize("GMT").tz_convert('CET').tz_localize(None)
df_gps= df_gps.set_index("time_CET")
df_gps = df_gps.sort_index(ascending=True)
df_gps
# Out:
#                          latitude (°)  longitude (°)  distance (km)  \
# time_CET
# 2023-02-28 10:33:17.136     41.910707      12.476449       0.000000
# 2023-02-28 10:35:18.000     41.910713      12.476418       0.002665
# 2023-02-28 10:37:19.000     41.910680      12.476336       0.010384
# 2023-02-28 10:39:06.000     41.910732      12.476434       0.020392
# 2023-02-28 10:41:07.000     41.910676      12.476492       0.028195
# ...                               ...            ...            ...
# 2023-02-28 12:52:01.000     41.905513      12.483953       6.309155
# 2023-02-28 12:52:13.000     41.905501      12.484088       6.320444
# 2023-02-28 12:52:19.000     41.905461      12.484198       6.330619
# 2023-02-28 12:52:24.000     41.905422      12.484338       6.343016
# 2023-02-28 12:55:52.000     41.906158      12.484462       6.425386
#
#                          compass (°)  duration (s)  velocity (km/h)  \
# time_CET
# 2023-02-28 10:33:17.136   282.658637         0.000         0.079378
# 2023-02-28 10:35:18.000   262.385479       120.864         0.154475
# 2023-02-28 10:37:19.000   328.645575       241.864         0.286474
# 2023-02-28 10:39:06.000    98.552810       348.864         0.287647
# 2023-02-28 10:41:07.000    88.420928       469.864         0.156243
# ...                              ...           ...              ...
# 2023-02-28 12:52:01.000   106.211092      8323.864         5.254500
# 2023-02-28 12:52:13.000   106.483369      8335.864         5.198900
# 2023-02-28 12:52:19.000   113.265065      8341.864         7.643640
# 2023-02-28 12:52:24.000    58.777930      8346.864         8.749779
# 2023-02-28 12:55:52.000     7.161679      8554.864         1.425635
#
#                          elevation (m)
# time_CET
# 2023-02-28 10:33:17.136           53.0
# 2023-02-28 10:35:18.000           59.0
# 2023-02-28 10:37:19.000           54.0
# 2023-02-28 10:39:06.000           60.0
# 2023-02-28 10:41:07.000           64.0
# ...                                ...
# 2023-02-28 12:52:01.000           76.0
# 2023-02-28 12:52:13.000           76.0
# 2023-02-28 12:52:19.000           76.0
# 2023-02-28 12:52:24.000           77.0
# 2023-02-28 12:55:52.000           42.0
#
# [517 rows x 7 columns]

# %%
#gps_data.map(embed=True)

# %% [markdown]
# ## resampling to seconds and interpolating

# %%
df_gps = df_gps.resample("s").interpolate("linear")
df_gps
# Out:
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# time_CET
# 2023-02-28 10:33:17           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:18           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:19           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:20           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:21           NaN            NaN            NaN          NaN
# ...                           ...            ...            ...          ...
# 2023-02-28 12:55:48     41.906143      12.484460       6.423802     8.154299
# 2023-02-28 12:55:49     41.906147      12.484461       6.424198     7.906144
# 2023-02-28 12:55:50     41.906151      12.484461       6.424594     7.657989
# 2023-02-28 12:55:51     41.906154      12.484462       6.424990     7.409834
# 2023-02-28 12:55:52     41.906158      12.484462       6.425386     7.161679
#
#                      duration (s)  velocity (km/h)  elevation (m)
# time_CET
# 2023-02-28 10:33:17           NaN              NaN            NaN
# 2023-02-28 10:33:18           NaN              NaN            NaN
# 2023-02-28 10:33:19           NaN              NaN            NaN
# 2023-02-28 10:33:20           NaN              NaN            NaN
# 2023-02-28 10:33:21           NaN              NaN            NaN
# ...                           ...              ...            ...
# 2023-02-28 12:55:48      8550.864         1.566484      42.673077
# 2023-02-28 12:55:49      8551.864         1.531271      42.504808
# 2023-02-28 12:55:50      8552.864         1.496059      42.336538
# 2023-02-28 12:55:51      8553.864         1.460847      42.168269
# 2023-02-28 12:55:52      8554.864         1.425635      42.000000
#
# [8556 rows x 7 columns]

# %%
# df_gps.loc['2023-02-27 09:57:13', :]

# %% [markdown]
# # Getting gas sensor data

# %%
time_correction_factor_gas = pd.Timedelta(hours=0, minutes=0, seconds=0)

air_q_files = []
for file in sorted(os.listdir(folder)):
    if file.startswith("data_gas"):
        air_q_files.append(os.path.join(folder, file))
print(sorted(air_q_files))

df_gas = pd.DataFrame()
for file in air_q_files:
    df_gas_temp = pd.read_csv(file, sep=",", index_col="Date/Time")
    df_gas = pd.concat([df_gas, df_gas_temp])
# df_gas

# df_gas = pd.read_csv("/content/datathink_2023/test_roma_20230226/data.csv", sep=",", index_col="Date/Time")
df_gas["time"] = pd.to_datetime(df_gas.index) - time_correction_factor_gas
df_gas = df_gas.set_index("time")
df_gas
# Out:
# []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## grouping per time (index) for avoiding errors due to duplicated indexes

# %%
df_gas = df_gas.groupby(by="time", as_index=True).agg("mean")

# %% [markdown]
# ## resampling to seconds and interpolating

# %%
df_gas = df_gas.resample("s").interpolate("linear")
df_gas
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# df_gas.loc['2023-02-27 09:57:13', :]
len(df_gas)
# Out:
# 0

# %% [markdown]
# # Getting GQ data

# %%
# in test file emfhistory_02242023_145731.csv last timestamp is 2023/02/24 18:57:09, but file was writen at 15:06:39. Shift: 3:50:30
time_correction_factor_GQ = pd.Timedelta(hours=3, minutes=50, seconds=30) 


GQ_files = []
for file in sorted(os.listdir(folder)):
    if file.startswith("emfhistory") and file.endswith(".csv"):
        GQ_files.append(os.path.join(folder, file))
print(sorted(GQ_files))

df_GQ = pd.DataFrame()
for file in GQ_files:
    df_GQ_temp = pd.read_csv(file, sep=",", header=[2])
    df_GQ = pd.concat([df_GQ, df_GQ_temp])


# df_GQ = pd.read_csv("emfhistory_02272023_012226.csv", sep=",", header=[2])
names_cols_GQ = {"mG":"EMF(mG)", 
                 "V/m": "EF(V/m)", 
                 "mW/m2": "RF Power Density(mW/m2)", 
                 "mW/cm2": "RF Power Density(mW/cm2)", 
                 "pW/cm2": "RF Power Density(pW/cm2)"}
df_GQ = df_GQ.rename(columns=names_cols_GQ)

df_GQ["time"] = pd.to_datetime(df_GQ["Date and Time"])# - time_correction_factor_GQ
df_GQ = df_GQ.set_index("time")
df_GQ
# Out:
# ['/content/datathink_2023/test_roma_20230228/sensor_GQ/emfhistory_02282023_142951.csv']
#                            Date and Time  EMF(mG)  EF(V/m)  \
# time
# 2023-02-27 12:34:16  2023/02/27 12:34:16      0.4      9.5
# 2023-02-27 12:34:17  2023/02/27 12:34:17      0.4      9.5
# 2023-02-27 12:34:18  2023/02/27 12:34:18      0.4      9.5
# 2023-02-27 12:34:19  2023/02/27 12:34:19      0.4     14.5
# 2023-02-28 10:13:33  2023/02/28 10:13:33      0.0      1.5
# ...                                  ...      ...      ...
# 2023-02-28 14:13:56  2023/02/28 14:13:56      0.4    264.2
# 2023-02-28 14:13:57  2023/02/28 14:13:57      0.4    255.8
# 2023-02-28 14:13:58  2023/02/28 14:13:58      0.5    576.5
# 2023-02-28 14:13:59  2023/02/28 14:13:59      0.6    832.5
# 2023-02-28 14:14:00  2023/02/28 14:14:00      0.6    737.5
#
#                      RF Power Density(mW/m2)  RF Power Density(mW/cm2)  \
# time
# 2023-02-27 12:34:16                   18.658                     0.002
# 2023-02-27 12:34:17                   18.658                     0.002
# 2023-02-27 12:34:18                   18.658                     0.002
# 2023-02-27 12:34:19                   18.658                     0.002
# 2023-02-28 10:13:33                    0.000                     0.000
# ...                                      ...                       ...
# 2023-02-28 14:13:56                   61.095                     0.006
# 2023-02-28 14:13:57                   24.244                     0.002
# 2023-02-28 14:13:58                   25.984                     0.003
# 2023-02-28 14:13:59                   22.103                     0.002
# 2023-02-28 14:14:00                    3.243                     0.000
#
#                      RF Power Density(pW/cm2)  Possible Source
# time
# 2023-02-27 12:34:16               1865770.125       WiFi/Phone
# 2023-02-27 12:34:17               1865770.125       WiFi/Phone
# 2023-02-27 12:34:18               1865770.125       WiFi/Phone
# 2023-02-27 12:34:19               1865770.125       WiFi/Phone
# 2023-02-28 10:13:33                     0.000           Static
# ...                                       ...              ...
# 2023-02-28 14:13:56               6109492.500            Mixed
# 2023-02-28 14:13:57               2424401.000            Mixed
# 2023-02-28 14:13:58               2598437.250            Mixed
# 2023-02-28 14:13:59               2210343.500            Mixed
# 2023-02-28 14:14:00                324273.375            Mixed
#
# [14465 rows x 7 columns]

# %%
len(df_GQ)#.loc['2023-02-27 09:57:13', :]
# Out:
# 14465

# %% [markdown]
# # merging

# %%
#df_merge = df_gps.merge(df_gas, how="left", left_index=True, right_index=True).merge(df_GQ, left_index=True, right_index=True)

# %%
if len(df_GQ)>0 and len(df_gas)>0: 
  df_merge = df_gps.merge(df_gas, how="left", left_index=True, right_index=True).merge(df_GQ, left_index=True, right_index=True)
elif len(df_GQ)==0:
  df_merge = df_gps.merge(df_gas, how="left", left_index=True, right_index=True)
elif len(df_gas)==0:
    df_merge = df_gps.merge(df_GQ, left_index=True, right_index=True)

# %%
df_merge#.head(10)
# Out:
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# 2023-02-28 10:33:17           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:18           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:19           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:20           NaN            NaN            NaN          NaN
# 2023-02-28 10:33:21           NaN            NaN            NaN          NaN
# ...                           ...            ...            ...          ...
# 2023-02-28 12:55:48     41.906143      12.484460       6.423802     8.154299
# 2023-02-28 12:55:49     41.906147      12.484461       6.424198     7.906144
# 2023-02-28 12:55:50     41.906151      12.484461       6.424594     7.657989
# 2023-02-28 12:55:51     41.906154      12.484462       6.424990     7.409834
# 2023-02-28 12:55:52     41.906158      12.484462       6.425386     7.161679
#
#                      duration (s)  velocity (km/h)  elevation (m)  \
# 2023-02-28 10:33:17           NaN              NaN            NaN
# 2023-02-28 10:33:18           NaN              NaN            NaN
# 2023-02-28 10:33:19           NaN              NaN            NaN
# 2023-02-28 10:33:20           NaN              NaN            NaN
# 2023-02-28 10:33:21           NaN              NaN            NaN
# ...                           ...              ...            ...
# 2023-02-28 12:55:48      8550.864         1.566484      42.673077
# 2023-02-28 12:55:49      8551.864         1.531271      42.504808
# 2023-02-28 12:55:50      8552.864         1.496059      42.336538
# 2023-02-28 12:55:51      8553.864         1.460847      42.168269
# 2023-02-28 12:55:52      8554.864         1.425635      42.000000
#
#                            Date and Time  EMF(mG)  EF(V/m)  \
# 2023-02-28 10:33:17  2023/02/28 10:33:17      0.4      1.3
# 2023-02-28 10:33:18  2023/02/28 10:33:18      0.4      1.1
# 2023-02-28 10:33:19  2023/02/28 10:33:19      0.4      1.1
# 2023-02-28 10:33:20  2023/02/28 10:33:20      0.4      1.9
# 2023-02-28 10:33:21  2023/02/28 10:33:21      0.4      1.1
# ...                                  ...      ...      ...
# 2023-02-28 12:55:48  2023/02/28 12:55:48      0.3      1.0
# 2023-02-28 12:55:49  2023/02/28 12:55:49      0.3      0.0
# 2023-02-28 12:55:50  2023/02/28 12:55:50      0.3      0.6
# 2023-02-28 12:55:51  2023/02/28 12:55:51      0.3      0.6
# 2023-02-28 12:55:52  2023/02/28 12:55:52      0.3      0.6
#
#                      RF Power Density(mW/m2)  RF Power Density(mW/cm2)  \
# 2023-02-28 10:33:17                    0.100                       0.0
# 2023-02-28 10:33:18                    0.586                       0.0
# 2023-02-28 10:33:19                    1.253                       0.0
# 2023-02-28 10:33:20                    0.793                       0.0
# 2023-02-28 10:33:21                    1.196                       0.0
# ...                                      ...                       ...
# 2023-02-28 12:55:48                    0.009                       0.0
# 2023-02-28 12:55:49                    0.002                       0.0
# 2023-02-28 12:55:50                    0.002                       0.0
# 2023-02-28 12:55:51                    0.006                       0.0
# 2023-02-28 12:55:52                    0.016                       0.0
#
#                      RF Power Density(pW/cm2)  Possible Source
# 2023-02-28 10:33:17                 10022.333            Mixed
# 2023-02-28 10:33:18                 58557.145            Mixed
# 2023-02-28 10:33:19                125334.531            Mixed
# 2023-02-28 10:33:20                 79314.992            Mixed
# 2023-02-28 10:33:21                119643.680            Mixed
# ...                                       ...              ...
# 2023-02-28 12:55:48                   925.239            Mixed
# 2023-02-28 12:55:49                   219.250            Mixed
# 2023-02-28 12:55:50                   164.328            Mixed
# 2023-02-28 12:55:51                   640.627            Mixed
# 2023-02-28 12:55:52                  1616.107            Mixed
#
# [8578 rows x 14 columns]

# %%
df_merge.to_csv("{}/20230228_ROMA_test_v4_merged_{}.csv".format(folder, folder.split("/")[-1]), sep=",")

# %%
print("{}/20230228_ROMA_test_v4_merged_{}.csv".format(folder, folder.split("/")[-1]))
# Out:
# /content/datathink_2023/test_roma_20230228/sensor_GQ/20230228_ROMA_test_v4_merged_sensor_GQ.csv
