# %% [markdown]
# # Datathink 2023
# Roma 2023. Biblioteca Hertziana + DSV@UZH + Max Planck Society
# # Sensing data fusion
# Javier Argota Sánchez-Vaquerizo
#
# *Computational Social Science* | **ETHZ Zürich**
# javier.argota@gess.ethz.ch
#
#
# This notebook illustrates how to combine and aggregates different types of data collected from different sensors:
# - GPS tracks from location devices (i.e. smartphones, smartwatches, activity trackers, etc.)
# - Gas / air quality data from the CoCi's CoSense unit by COSS@ETHZ
# - GQ multimeter for electric+electromagnetic+radiofrequency

# %%
# We first mount your Google Drive folder in that notebook so that we can download and upload files.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Reivajar/datathink_2023.git
# Out:
# Cloning into 'datathink_2023'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 44 (delta 12), reused 40 (delta 11), pack-reused 0
# Unpacking objects: 100% (44/44), 3.89 MiB | 4.10 MiB/s, done.

# %%
# install libraries
# !pip install gpxo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gpxo
#   Downloading gpxo-0.1.6-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from gpxo) (1.22.4)
# Collecting vincenty
#   Downloading vincenty-0.1.4.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from gpxo) (6.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from gpxo) (1.3.5)
# Collecting mplleaflet
#   Downloading mplleaflet-0.0.5.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gpxpy
#   Downloading gpxpy-1.5.0.tar.gz (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.6/111.6 KB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from gpxo) (3.5.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->gpxo) (3.14.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gpxo) (3.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from mplleaflet->gpxo) (2.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from mplleaflet->gpxo) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->gpxo) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->mplleaflet->gpxo) (2.0.1)
# Building wheels for collected packages: gpxpy, mplleaflet, vincenty
#   Building wheel for gpxpy (setup.py) ... done
#   Created wheel for gpxpy: filename=gpxpy-1.5.0-py3-none-any.whl size=42899 sha256=66569f3cda00e980871d47c4dd63806d5f8ad455138ff57b84f9278e1574978b
#   Stored in directory: /root/.cache/pip/wheels/93/15/ce/1cd2782b440b8a517b89c3fa112f79f7015bd6e51b552e1b1a
#   Building wheel for mplleaflet (setup.py) ... done
#   Created wheel for mplleaflet: filename=mplleaflet-0.0.5-py3-none-any.whl size=28582 sha256=6132e900a31e564a5451806c5a052d823e7ba1a0c3cc07d30f2656270bbb2aa7
#   Stored in directory: /root/.cache/pip/wheels/d4/a9/cf/8c4753b208759e9509ade040a94c3d4271f1756f529c575dc8
#   Building wheel for vincenty (setup.py) ... done
#   Created wheel for vincenty: filename=vincenty-0.1.4-py3-none-any.whl size=3080 sha256=b8e8da3e8a0e5245413bf718966ccd8559e82d266a7efe0068f48a3b4c3d6d67
#   Stored in directory: /root/.cache/pip/wheels/90/30/48/3351a4a3383a4b869c80caf348f89941c33b1f8ad593d0b439
# Successfully built gpxpy mplleaflet vincenty
# Installing collected packages: vincenty, gpxpy, mplleaflet, gpxo
# Successfully installed gpxo-0.1.6 gpxpy-1.5.0 mplleaflet-0.0.5 vincenty-0.1.4

# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Defining wd

# %%
folder = "/content/datathink_2023/test_roma_20230226-27" #os.getcwd()

# %% [markdown]
# # Importing GPS tracks

# %% [markdown]
# ## method 2 with gpxo

# %%
import gpxo
paths = []
for file in sorted(os.listdir(folder)):
    if file.endswith(".gpx"):
        paths.append(os.path.join(folder, file))
print(sorted(paths))

df_gps = pd.DataFrame()
for gps_tracks in paths:
    gps_data = gpxo.Track(gps_tracks)
    df_gps_temp = gps_data.data
    df_gps = pd.concat([df_gps, df_gps_temp])
df_gps
# Out:
# ['/content/datathink_2023/test_roma_20230226-27/data_gps_01.gpx', '/content/datathink_2023/test_roma_20230226-27/data_gps_02.gpx']
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# time
# 2023-02-26 16:38:56     41.903963      12.485487       0.000000   328.038520
# 2023-02-26 16:39:12     41.903972      12.485480       0.001094   258.570558
# 2023-02-26 16:39:34     41.903963      12.485478       0.002128   190.889652
# 2023-02-26 16:39:45     41.903953      12.485475       0.003191   201.081261
# 2023-02-26 16:40:07     41.903940      12.485465       0.004916   257.757030
# ...                           ...            ...            ...          ...
# 2023-02-27 09:38:55     41.904250      12.485427       3.724111    18.338827
# 2023-02-27 09:40:56     41.904251      12.485427       3.724155   348.824543
# 2023-02-27 09:47:00     41.904261      12.485428       3.725319     5.445948
# 2023-02-27 09:50:01     41.904262      12.485428       3.725405     5.208844
# 2023-02-27 09:57:13     41.904263      12.485428       3.725563     2.700727
#
#                      duration (s)  velocity (km/h)  elevation (m)
# time
# 2023-02-26 16:38:56           0.0         0.246150          89.27
# 2023-02-26 16:39:12          16.0         0.213750          88.24
# 2023-02-26 16:39:34          38.0         0.288327          88.29
# 2023-02-26 16:39:45          49.0         0.326018          89.31
# 2023-02-26 16:40:07          71.0         1.456305          89.37
# ...                           ...              ...            ...
# 2023-02-27 09:38:55        3624.0         0.006459          98.70
# 2023-02-27 09:40:56        3745.0         0.003855          98.92
# 2023-02-27 09:47:00        4109.0         0.004966          98.72
# 2023-02-27 09:50:01        4290.0         0.001594          99.07
# 2023-02-27 09:57:13        4722.0         0.001317          98.43
#
# [6899 rows x 7 columns]

# %%
df_gps.index
# Out:
# DatetimeIndex(['2023-02-26 16:38:56', '2023-02-26 16:39:12',
#                '2023-02-26 16:39:34', '2023-02-26 16:39:45',
#                '2023-02-26 16:40:07', '2023-02-26 16:40:10',
#                '2023-02-26 16:40:11', '2023-02-26 16:40:12',
#                '2023-02-26 16:40:14', '2023-02-26 16:40:55',
#                ...
#                '2023-02-27 09:34:48', '2023-02-27 09:35:03',
#                '2023-02-27 09:35:12', '2023-02-27 09:35:14',
#                '2023-02-27 09:35:16', '2023-02-27 09:38:55',
#                '2023-02-27 09:40:56', '2023-02-27 09:47:00',
#                '2023-02-27 09:50:01', '2023-02-27 09:57:13'],
#               dtype='datetime64[ns]', name='time', length=6899, freq=None)

# %%
# read Datetime Index in GMT, convert to CET and remove timezone while preserving local time
df_gps["time_CET"] = df_gps.index.tz_localize("GMT").tz_convert('CET').tz_localize(None)
df_gps= df_gps.set_index("time_CET")
df_gps = df_gps.sort_index(ascending=True)
df_gps
# Out:
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# time_CET
# 2023-02-26 17:38:56     41.903963      12.485487       0.000000   328.038520
# 2023-02-26 17:39:12     41.903972      12.485480       0.001094   258.570558
# 2023-02-26 17:39:34     41.903963      12.485478       0.002128   190.889652
# %% [markdown]
# # Getting gas sensor data

# %%
time_correction_factor_gas = pd.Timedelta(hours=0, minutes=0, seconds=0)

air_q_files = []
for file in sorted(os.listdir(folder)):
    if file.startswith("data_gas"):
        air_q_files.append(os.path.join(folder, file))
print(sorted(air_q_files))

df_gas = pd.DataFrame()
for file in air_q_files:
    df_gas_temp = pd.read_csv(file, sep=",", index_col="Date/Time")
    df_gas = pd.concat([df_gas, df_gas_temp])
# df_gas

# df_gas = pd.read_csv("/content/datathink_2023/test_roma_20230226/data.csv", sep=",", index_col="Date/Time")
df_gas["time"] = pd.to_datetime(df_gas.index) - time_correction_factor_gas
df_gas = df_gas.set_index("time")
df_gas
# Out:
# ['/content/datathink_2023/test_roma_20230226-27/data_gas_01.csv', '/content/datathink_2023/test_roma_20230226-27/data_gas_02.csv']
#                      Temperature (C)  Humidity (%)  PM1 (ug/m3)  \
# time
# 2023-02-23 17:40:54        20.690475     39.124599         2.71
# 2023-02-23 17:43:19        21.646548     39.015591         4.69
# 2023-02-23 17:44:20        22.337467     38.364841         2.60
# 2023-02-23 17:45:19        22.976740     38.016118         6.02
# 2023-02-23 17:46:20        23.021676     37.418868         4.24
# ...                              ...           ...          ...
# 2023-02-27 10:32:02        14.049507     58.698119         1.15
# 2023-02-27 10:32:20        13.896886     58.624933         1.53
# 2023-02-27 11:53:34        14.515218     57.629262         1.04
# 2023-02-27 11:53:54        14.891834     56.598850         1.35
# 2023-02-27 11:54:20        15.085200     55.543762         3.71
#
#                      PM2.5 (ug/m3)  PM10 (ug/m3)
# time
# 2023-02-23 17:40:54           7.26         12.19
# 2023-02-23 17:43:19           9.19         13.82
# 2023-02-23 17:44:20           6.28         10.21
# 2023-02-23 17:45:19           6.63          6.63
# 2023-02-23 17:46:20          14.03         24.82
# ...                            ...           ...
# 2023-02-27 10:32:02           4.21          7.61
# 2023-02-27 10:32:20           2.82          4.13
# 2023-02-27 11:53:34           3.38          5.95
# 2023-02-27 11:53:54           1.48          1.48
# 2023-02-27 11:54:20          10.40         17.67
#
# [2653 rows x 5 columns]

# %% [markdown]
# ## grouping per time (index) for avoiding errors due to duplicated indexes

# %%
df_gas = df_gas.groupby(by="time", as_index=True).agg("mean")

# %% [markdown]
# ## resampling to seconds and interpolating

# %%
df_gas = df_gas.resample("s").interpolate("linear")
df_gas
# Out:
#                      Temperature (C)  Humidity (%)  PM1 (ug/m3)  \
# time
# 2023-02-23 17:40:54        20.690475     39.124599     2.710000
# 2023-02-23 17:40:55        20.697068     39.123848     2.723655
# 2023-02-23 17:40:56        20.703662     39.123096     2.737310
# 2023-02-23 17:40:57        20.710256     39.122344     2.750966
# 2023-02-23 17:40:58        20.716849     39.121592     2.764621
# ...                              ...           ...          ...
# 2023-02-27 11:54:16        15.055451     55.706083     3.346923
# 2023-02-27 11:54:17        15.062888     55.665503     3.437692
# 2023-02-27 11:54:18        15.070326     55.624923     3.528462
# 2023-02-27 11:54:19        15.077763     55.584342     3.619231
# 2023-02-27 11:54:20        15.085200     55.543762     3.710000
#
#                      PM2.5 (ug/m3)  PM10 (ug/m3)
# time
# 2023-02-23 17:40:54       7.260000     12.190000
# 2023-02-23 17:40:55       7.273310     12.201241
# 2023-02-23 17:40:56       7.286621     12.212483
# 2023-02-23 17:40:57       7.299931     12.223724
# 2023-02-23 17:40:58       7.313241     12.234966
# ...                            ...           ...
# 2023-02-27 11:54:16       9.027692     15.179231
# 2023-02-27 11:54:17       9.370769     15.801923
# 2023-02-27 11:54:18       9.713846     16.424615
# 2023-02-27 11:54:19      10.056923     17.047308
# 2023-02-27 11:54:20      10.400000     17.670000
#
# [324807 rows x 5 columns]

# %%
df_gas.loc['2023-02-27 09:57:13', :]
# Out:
# Temperature (C)     9.308648
# Humidity (%)       68.001994
# PM1 (ug/m3)         3.782333
# PM2.5 (ug/m3)       4.173167
# PM10 (ug/m3)        4.173167
# Name: 2023-02-27 09:57:13, dtype: float64

# %% [markdown]
# # Getting GQ data

# %%
# in test file emfhistory_02242023_145731.csv last timestamp is 2023/02/24 18:57:09, but file was writen at 15:06:39. Shift: 3:50:30
time_correction_factor_GQ = pd.Timedelta(hours=3, minutes=50, seconds=30) 


GQ_files = []
for file in sorted(os.listdir(folder)):
    if file.startswith("emfhistory") and file.endswith(".csv"):
        GQ_files.append(os.path.join(folder, file))
print(sorted(GQ_files))

df_GQ = pd.DataFrame()
for file in GQ_files:
    df_GQ_temp = pd.read_csv(file, sep=",", header=[2])
    df_GQ = pd.concat([df_GQ, df_GQ_temp])


# df_GQ = pd.read_csv("emfhistory_02272023_012226.csv", sep=",", header=[2])
names_cols_GQ = {"mG":"EMF(mG)", 
                 "V/m": "EF(V/m)", 
                 "mW/m2": "RF Power Density(mW/m2)", 
                 "mW/cm2": "RF Power Density(mW/cm2)", 
                 "pW/cm2": "RF Power Density(pW/cm2)"}
df_GQ = df_GQ.rename(columns=names_cols_GQ)

df_GQ["time"] = pd.to_datetime(df_GQ["Date and Time"])# - time_correction_factor_GQ
df_GQ = df_GQ.set_index("time")
df_GQ
# Out:
# ['/content/datathink_2023/test_roma_20230226-27/emfhistory_02272023_012226.csv', '/content/datathink_2023/test_roma_20230226-27/emfhistory_02272023_114813.csv']
#                            Date and Time  EMF(mG)  EF(V/m)  \
# time
# 2023-02-26 00:00:59  2023/02/26 00:00:59      0.6      1.1
# 2023-02-26 00:01:00  2023/02/26 00:01:00      0.6      1.1
# 2023-02-26 00:01:01  2023/02/26 00:01:01      0.6      1.1
# 2023-02-26 00:01:02  2023/02/26 00:01:02      0.6      1.1
# 2023-02-26 00:01:03  2023/02/26 00:01:03      0.6     24.5
# ...                                  ...      ...      ...
# 2023-02-27 11:46:15  2023/02/27 11:46:15      0.3     20.5
# 2023-02-27 11:46:16  2023/02/27 11:46:16      0.3     22.5
# 2023-02-27 11:46:17  2023/02/27 11:46:17      0.4     23.5
# 2023-02-27 11:46:18  2023/02/27 11:46:18      0.4     55.1
# 2023-02-27 11:46:19  2023/02/27 11:46:19      0.3     65.6
#
#                      RF Power Density(mW/m2)  RF Power Density(mW/cm2)  \
# time
# 2023-02-26 00:00:59                    3.144                     0.000
# 2023-02-26 00:01:00                    3.144                     0.000
# 2023-02-26 00:01:01                    3.144                     0.000
# 2023-02-26 00:01:02                    3.144                     0.000
# 2023-02-26 00:01:03                   15.154                     0.002
# ...                                      ...                       ...
# 2023-02-27 11:46:15                    3.218                     0.000
# 2023-02-27 11:46:16                    3.293                     0.000
# 2023-02-27 11:46:17                    5.034                     0.001
# 2023-02-27 11:46:18                    4.314                     0.000
# 2023-02-27 11:46:19                    4.518                     0.000
#
#                      RF Power Density(pW/cm2)  Possible Source
# time
# 2023-02-26 00:00:59                314415.875       WiFi/Phone
# 2023-02-26 00:01:00                314415.875       WiFi/Phone
# 2023-02-26 00:01:01                314415.875       WiFi/Phone
# 2023-02-26 00:01:02                314415.875       WiFi/Phone
# 2023-02-26 00:01:03               1515382.625       WiFi/Phone
# ...                                       ...              ...
# 2023-02-27 11:46:15                321780.438       WiFi/Phone
# 2023-02-27 11:46:16                329317.156            Mixed
# 2023-02-27 11:46:17                503354.125       WiFi/Phone
# 2023-02-27 11:46:18                431405.344            Mixed
# 2023-02-27 11:46:19                451838.906            Mixed
#
# [68444 rows x 7 columns]

# %%
df_GQ.loc['2023-02-27 09:57:13', :]
# Out:
#                            Date and Time  EMF(mG)  EF(V/m)  \
# time
# 2023-02-27 09:57:13  2023/02/27 09:57:13      1.9      1.2
#
#                      RF Power Density(mW/m2)  RF Power Density(mW/cm2)  \
# time
# 2023-02-27 09:57:13                    0.127                       0.0
#
#                      RF Power Density(pW/cm2)  Possible Source
# time
# 2023-02-27 09:57:13                 12705.289       WiFi/Phone

# %% [markdown]
# # merging

# %%
df_merge = df_gps.merge(df_gas, how="left", left_index=True, right_index=True).merge(df_GQ, left_index=True, right_index=True)

# %%
df_merge#.head(10)
# Out:
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# 2023-02-26 17:41:00     41.904009      12.485442       0.013558   294.708345
# 2023-02-26 17:41:00     41.904009      12.485442       0.013558   294.708345
# 2023-02-26 17:41:01     41.904006      12.485438       0.014022   289.825418
# 2023-02-26 17:41:01     41.904006      12.485438       0.014022   289.825418
# 2023-02-26 17:41:02     41.904003      12.485433       0.014486   284.942491
# ...                           ...            ...            ...          ...
# 2023-02-27 10:57:09     41.904263      12.485428       3.725562     2.723951
# 2023-02-27 10:57:10     41.904263      12.485428       3.725562     2.718145
# 2023-02-27 10:57:11     41.904263      12.485428       3.725562     2.712339
# 2023-02-27 10:57:12     41.904263      12.485428       3.725563     2.706533
# 2023-02-27 10:57:13     41.904263      12.485428       3.725563     2.700727
#
#                      duration (s)  velocity (km/h)  elevation (m)  \
# 2023-02-26 17:41:00         124.0         0.995074      76.450000
# 2023-02-26 17:41:00         124.0         0.995074      76.450000
# 2023-02-26 17:41:01         125.0         1.473882      76.356923
# 2023-02-26 17:41:01         125.0         1.473882      76.356923
# 2023-02-26 17:41:02         126.0         1.952691      76.263846
# ...                           ...              ...            ...
# 2023-02-27 10:57:09        4718.0         0.001319      98.435926
# 2023-02-27 10:57:10        4719.0         0.001319      98.434444
# 2023-02-27 10:57:11        4720.0         0.001318      98.432963
# 2023-02-27 10:57:12        4721.0         0.001317      98.431481
# 2023-02-27 10:57:13        4722.0         0.001317      98.430000
#
#                      Temperature (C)  Humidity (%)  PM1 (ug/m3)  \
# 2023-02-26 17:41:00        16.507948     47.437417     2.170000
# 2023-02-26 17:41:00        16.507948     47.437417     2.170000
